# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data load and explore

# %%
df = pd.read_csv('D:/Projects/Credit Card Churn Prediction/dataset/credit_card_churn.csv')
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %%
df.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %%
df.isnull().sum()
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# ...

# %%
df.shape
# Out:
# (10127, 23)

# %%
df.columns.values
# Out:
# array(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype=object)

# %%
df.dtypes
# Out:
# CLIENTNUM                                                                                                                               int64
# Attrition_Flag                                                                                                                         object
# Customer_Age                                                                                                                            int64
# Gender                                                                                                                                 object
# Dependent_count                                                                                                                         int64
# Education_Level                                                                                                                        object
# ...

# %%
# deleting the last two columns as suggested in the data card

df = df.drop(['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1', 
              'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'], axis = 1)

# %%
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# ...

# %%
df.shape
# Out:
# (10127, 21)

# %% [markdown]
# ### Value count and plots of basic information of customer

# %%
print(df['Customer_Age'].value_counts())
sns.countplot(y = 'Customer_Age', data = df)
# Out:
# Customer_Age
# 44    500
# 49    495
# 46    490
# 45    486
# 47    479
# 43    473
# 48    472
# 50    452
# 42    426
# 51    398
# 53    387
# 41    379
# 52    376
# 40    361
# 39    333
# 54    307
# 38    303
# 55    279
# 56    262
# 37    260
# 57    223
# 36    221
# 35    184
# 59    157
# 58    157
# 34    146
# 33    127
# 60    127
# 32    106
# 65    101
# 61     93
# 62     93
# 31     91
# 26     78
# 30     70
# 63     65
# 29     56
# 64     43
# 27     32
# 28     29
# 67      4
# 66      2
# 68      2
# 70      1
# 73      1
# Name: count, dtype: int64
# <Axes: xlabel='count', ylabel='Customer_Age'>

# %%
# target variable

print(df['Attrition_Flag'].value_counts())
sns.countplot(y = 'Attrition_Flag', data = df)
# Out:
# Attrition_Flag
# Existing Customer    8500
# Attrited Customer    1627
# Name: count, dtype: int64
# <Axes: xlabel='count', ylabel='Attrition_Flag'>

# %%
print(df['Gender'].value_counts())
sns.countplot(y = 'Gender', data = df)
# Out:
# Gender
# F    5358
# M    4769
# Name: count, dtype: int64
# <Axes: xlabel='count', ylabel='Gender'>

# %%
print(df['Education_Level'].value_counts())
sns.countplot(y = 'Education_Level', data = df)
# Out:
# Education_Level
# Graduate         3128
# High School      2013
# Unknown          1519
# Uneducated       1487
# College          1013
# Post-Graduate     516
# Doctorate         451
# Name: count, dtype: int64
# <Axes: xlabel='count', ylabel='Education_Level'>

# %%
print(df['Marital_Status'].value_counts())
sns.countplot(y = 'Marital_Status', data = df)
# Out:
# Marital_Status
# Married     4687
# Single      3943
# Unknown      749
# Divorced     748
# Name: count, dtype: int64
# <Axes: xlabel='count', ylabel='Marital_Status'>

# %%
print(df['Income_Category'].value_counts())
sns.countplot(y = 'Income_Category', data = df)
# Out:
# Income_Category
# Less than $40K    3561
# $40K - $60K       1790
# $80K - $120K      1535
# $60K - $80K       1402
# Unknown           1112
# $120K +            727
# Name: count, dtype: int64
# <Axes: xlabel='count', ylabel='Income_Category'>

# %%
print(df['Card_Category'].value_counts())
sns.countplot(y = 'Card_Category', data = df)
# Out:
# Card_Category
# Blue        9436
# Silver       555
# Gold         116
# Platinum      20
# Name: count, dtype: int64
# <Axes: xlabel='count', ylabel='Card_Category'>

# %% [markdown]
# ### Data Cleaning & Preparation

# %%
plt.boxplot(df['Credit_Limit'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18a02b65910>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18a02b66a50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18a02b65150>],
#  'medians': [<matplotlib.lines.Line2D at 0x18a02b67d10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18a02b74690>],
#  'means': []}

# %%
util_percentiles = df['Credit_Limit'].quantile([0.0, 0.05, 0.1, 0.25, 0.5, 0.6, 0.7, 0.75, 0.80, 0.85, 0.86, 0.87, 0.89, 0.90, 0.91, 0.92, 0.93, 0.94, 0.95, 0.96, 0.97, 0.975, 0.98, 0.99, 1.00])
round(util_percentiles, 2)
# Out:
# 0.000     1438.30
# 0.050     1438.51
# 0.100     1762.00
# 0.250     2555.00
# 0.500     4549.00
# 0.600     6279.20
# 0.700     9078.40
# 0.750    11067.50
# 0.800    13562.60
# 0.850    17455.40
# 0.860    18354.16
# 0.870    19314.88
# 0.890    21754.28
# 0.900    23400.20
# 0.910    24614.54
# 0.920    26680.40
# 0.930    29044.84
# 0.940    31688.36
# 0.950    34516.00
# 0.960    34516.00
# 0.970    34516.00
# 0.975    34516.00
# 0.980    34516.00
# 0.990    34516.00
# 1.000    34516.00
# Name: Credit_Limit, dtype: float64

# %%
median_util = df['Credit_Limit'].median()
median_util
# Out:
# 4549.0

# %%
mean_util = df['Credit_Limit'].mean()
mean_util
# Out:
# 8631.953698034955

# %%
util_temp_bool_vect = df['Credit_Limit'] > 32000

df['util_new'] = df['Credit_Limit']
df['util_new'][util_temp_bool_vect] = median_util
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_18912\2032249679.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['util_new'][util_temp_bool_vect] = median_util

# %%
util_percentiles1 = df['util_new'].quantile([0.05, 0.1, 0.25, 0.5, 0.75, 0.80, 0.90, 0.91, 0.95, 0.96, 0.97, 0.975, 0.98, 0.99, 1.00])
round(util_percentiles1, 2)
# Out:
# 0.050     1438.51
# 0.100     1762.00
# 0.250     2555.00
# 0.500     4549.00
# 0.750     8804.50
# 0.800    10609.40
# 0.900    16578.20
# 0.910    17593.82
# 0.950    21917.20
# 0.960    23511.92
# 0.970    24888.40
# 0.975    25870.45
# 0.980    26829.08
# 0.990    29379.44
# 1.000    31987.00
# Name: util_new, dtype: float64

# %%
plt.boxplot(df['Total_Revolving_Bal'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18a02bc32d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18a02bd0650>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18a02ba0450>],
#  'medians': [<matplotlib.lines.Line2D at 0x18a02bd1690>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18a02bd1f90>],
#  'means': []}

# %%
util_percentiles = df['Total_Revolving_Bal'].quantile([0.0, 0.05, 0.1, 0.25, 0.5, 0.6, 0.7, 0.75, 0.80, 0.85, 0.86, 0.87, 0.89, 0.90, 0.91, 0.92, 0.93, 0.94, 0.95, 0.96, 0.97, 0.975, 0.98, 0.99, 1.00])
round(util_percentiles, 2)
# Out:
# 0.000       0.00
# 0.050       0.00
# 0.100       0.00
# 0.250     359.00
# 0.500    1276.00
# 0.600    1482.00
# 0.700    1673.20
# 0.750    1784.00
# 0.800    1903.00
# 0.850    2044.00
# 0.860    2078.36
# 0.870    2109.00
# 0.890    2191.14
# 0.900    2228.40
# 0.910    2275.32
# 0.920    2330.00
# 0.930    2387.18
# 0.940    2446.00
# 0.950    2517.00
# 0.960    2517.00
# 0.970    2517.00
# 0.975    2517.00
# 0.980    2517.00
# 0.990    2517.00
# 1.000    2517.00
# Name: Total_Revolving_Bal, dtype: float64

# %%
median_util = df['Total_Revolving_Bal'].median()
mean_util = df['Total_Revolving_Bal'].mean()
print("Mean is", mean_util, "and median is", median_util)
# Out:
# Mean is 1162.8140614199665 and median is 1276.0

# %%
plt.boxplot(df['Avg_Open_To_Buy'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18a02c2f6d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18a02c38b50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18a02c2ee10>],
#  'medians': [<matplotlib.lines.Line2D at 0x18a02c39c50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18a02c3a590>],
#  'means': []}

# %%
util_percentiles = df['Avg_Open_To_Buy'].quantile([0.0, 0.05, 0.1, 0.25, 0.5, 0.6, 0.7, 0.75, 0.80, 0.85, 0.86, 0.87, 0.89, 0.90, 0.91, 0.92, 0.93, 0.94, 0.95, 0.96, 0.97, 0.975, 0.98, 0.99, 1.00])
round(util_percentiles, 2)
# Out:
# 0.000        3.00
# 0.050      480.30
# 0.100      683.00
# 0.250     1324.50
# 0.500     3474.00
# 0.600     5195.00
# 0.700     7884.60
# 0.750     9859.00
# 0.800    12419.80
# 0.850    16260.90
# 0.860    17237.08
# 0.870    18322.10
# 0.890    20852.10
# 0.900    21964.60
# 0.910    23536.28
# 0.920    25479.00
# 0.930    27921.98
# 0.940    30375.12
# 0.950    32183.40
# 0.960    32651.72
# 0.970    33048.44
# 0.975    33208.85
# 0.980    33427.88
# 0.990    34294.14
# 1.000    34516.00
# Name: Avg_Open_To_Buy, dtype: float64

# %%
median_util = df['Avg_Open_To_Buy'].median()
mean_util = df['Avg_Open_To_Buy'].mean()
print("Mean is", mean_util, "and median is", median_util)
# Out:
# Mean is 7469.139636614989 and median is 3474.0

# %%
util_temp_bool_vect = df['Avg_Open_To_Buy'] > 25000

df['util_new'] = df['Avg_Open_To_Buy']
df['util_new'][util_temp_bool_vect] = median_util
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_18912\3594348189.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['util_new'][util_temp_bool_vect] = median_util

# %%
util_percentiles = df['util_new'].quantile([0.0, 0.05, 0.1, 0.25, 0.5, 0.6, 0.7, 0.75, 0.80, 0.85, 0.86, 0.87, 0.89, 0.90, 0.91, 0.92, 0.93, 0.94, 0.95, 0.96, 0.97, 0.975, 0.98, 0.99, 1.00])
round(util_percentiles, 2)
# Out:
# 0.000        3.00
# 0.050      480.30
# 0.100      683.00
# 0.250     1324.50
# 0.500     3474.00
# 0.600     3703.60
# 0.700     5611.20
# 0.750     6981.00
# 0.800     8529.00
# 0.850    10757.80
# 0.860    11224.32
# 0.870    11767.44
# 0.890    13080.84
# 0.900    13713.40
# 0.910    14479.32
# 0.920    15235.68
# 0.930    16044.26
# 0.940    17000.04
# 0.950    18039.10
# 0.960    19089.88
# 0.970    20474.44
# 0.975    21153.10
# 0.980    21746.72
# 0.990    23152.58
# 1.000    24973.00
# Name: util_new, dtype: float64

# %%
plt.boxplot(df['util_new'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18a03ef2350>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18a03ef36d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18a03ef1ad0>],
#  'medians': [<matplotlib.lines.Line2D at 0x18a03f04950>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18a03f05250>],
#  'means': []}

# %%
plt.boxplot(df['Total_Amt_Chng_Q4_Q1'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18a03f56090>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18a03f574d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18a03f55810>],
#  'medians': [<matplotlib.lines.Line2D at 0x18a03f602d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18a03f60ad0>],
#  'means': []}

# %%
util_percentiles = df['Total_Amt_Chng_Q4_Q1'].quantile([0.0, 0.05, 0.1, 0.25, 0.5, 0.6, 0.7, 0.75, 0.80, 0.85, 0.86, 0.87, 0.89, 0.90, 0.91, 0.92, 0.93, 0.94, 0.95, 0.96, 0.97, 0.975, 0.98, 0.99, 1.00])
round(util_percentiles, 2)
# Out:
# 0.000    0.00
# 0.050    0.46
# 0.100    0.53
# 0.250    0.63
# 0.500    0.74
# 0.600    0.78
# 0.700    0.83
# 0.750    0.86
# 0.800    0.89
# 0.850    0.94
# 0.860    0.95
# 0.870    0.96
# 0.890    0.98
# 0.900    1.00
# 0.910    1.01
# 0.920    1.03
# 0.930    1.04
# 0.940    1.06
# 0.950    1.10
# 0.960    1.16
# 0.970    1.24
# 0.975    1.28
# 0.980    1.33
# 0.990    1.51
# 1.000    3.40
# Name: Total_Amt_Chng_Q4_Q1, dtype: float64

# %%
median_util = df['Total_Amt_Chng_Q4_Q1'].median()
mean_util = df['Total_Amt_Chng_Q4_Q1'].mean()
print("Mean is", mean_util, "and median is", median_util)
# Out:
# Mean is 0.7599406536980349 and median is 0.736

# %%
plt.boxplot(df['Total_Trans_Amt'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18a02dbd490>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18a03eb9250>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18a03f63e50>],
#  'medians': [<matplotlib.lines.Line2D at 0x18a02dbf750>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18a02dc8090>],
#  'means': []}

# %%
util_percentiles = df['Total_Trans_Amt'].quantile([0.0, 0.05, 0.1, 0.25, 0.5, 0.6, 0.7, 0.75, 0.80, 0.85, 0.86, 0.87, 0.89, 0.90, 0.91, 0.92, 0.93, 0.94, 0.95, 0.96, 0.97, 0.975, 0.98, 0.99, 1.00])
round(util_percentiles, 2)
# Out:
# 0.000      510.00
# 0.050     1283.30
# 0.100     1501.00
# 0.250     2155.50
# 0.500     3899.00
# 0.600     4267.00
# 0.700     4572.00
# 0.750     4741.00
# 0.800     4926.00
# 0.850     5413.30
# 0.860     7041.36
# 0.870     7494.62
# 0.890     7936.42
# 0.900     8212.40
# 0.910     8568.30
# 0.920     9070.52
# 0.930    13065.60
# 0.940    13758.44
# 0.950    14212.00
# 0.960    14543.92
# 0.970    14932.44
# 0.975    15096.70
# 0.980    15281.48
# 0.990    15882.36
# 1.000    18484.00
# Name: Total_Trans_Amt, dtype: float64

# %%
median_util = df['Total_Trans_Amt'].median()
mean_util = df['Total_Trans_Amt'].mean()
print("Mean is", mean_util, "and median is", median_util)
# Out:
# Mean is 4404.086303939963 and median is 3899.0

# %%
plt.boxplot(df['Total_Trans_Ct'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18a02e186d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18a02e21410>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18a02e20110>],
#  'medians': [<matplotlib.lines.Line2D at 0x18a02e22550>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18a02e22d50>],
#  'means': []}

# %%
util_percentiles = df['Total_Trans_Ct'].quantile([0.0, 0.05, 0.1, 0.25, 0.5, 0.6, 0.7, 0.75, 0.80, 0.85, 0.86, 0.87, 0.89, 0.90, 0.91, 0.92, 0.93, 0.94, 0.95, 0.96, 0.97, 0.975, 0.98, 0.99, 1.00])
round(util_percentiles, 2)
# Out:
# 0.000     10.0
# 0.050     28.0
# 0.100     33.0
# 0.250     45.0
# 0.500     67.0
# 0.600     73.0
# 0.700     78.0
# 0.750     81.0
# 0.800     83.0
# 0.850     87.0
# 0.860     87.0
# 0.870     88.0
# 0.890     91.0
# 0.900     92.0
# 0.910     94.0
# 0.920     96.0
# 0.930     99.0
# 0.940    102.0
# 0.950    105.0
# 0.960    110.0
# 0.970    114.0
# 0.975    116.0
# 0.980    118.0
# 0.990    123.0
# 1.000    139.0
# Name: Total_Trans_Ct, dtype: float64

# %%
median_util = df['Total_Trans_Ct'].median()
mean_util = df['Total_Trans_Ct'].mean()
print("Mean is", mean_util, "and median is", median_util)
# Out:
# Mean is 64.85869457884863 and median is 67.0

# %%
plt.boxplot(df['Total_Ct_Chng_Q4_Q1'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18a02e89c50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18a02e8ae10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18a02e89550>],
#  'medians': [<matplotlib.lines.Line2D at 0x18a02e98250>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18a02e98cd0>],
#  'means': []}

# %%
util_percentiles = df['Total_Ct_Chng_Q4_Q1'].quantile([0.0, 0.05, 0.1, 0.25, 0.5, 0.6, 0.7, 0.75, 0.80, 0.85, 0.86, 0.87, 0.89, 0.90, 0.91, 0.92, 0.93, 0.94, 0.95, 0.96, 0.97, 0.975, 0.98, 0.99, 1.00])
round(util_percentiles, 2)
# Out:
# 0.000    0.00
# 0.050    0.37
# 0.100    0.45
# 0.250    0.58
# 0.500    0.70
# 0.600    0.74
# 0.700    0.79
# 0.750    0.82
# 0.800    0.85
# 0.850    0.89
# 0.860    0.90
# 0.870    0.92
# 0.890    0.94
# 0.900    0.95
# 0.910    0.97
# 0.920    1.00
# 0.930    1.00
# 0.940    1.03
# 0.950    1.07
# 0.960    1.11
# 0.970    1.17
# 0.975    1.21
# 0.980    1.27
# 0.990    1.46
# 1.000    3.71
# Name: Total_Ct_Chng_Q4_Q1, dtype: float64

# %%
median_util = df['Total_Ct_Chng_Q4_Q1'].median()
mean_util = df['Total_Ct_Chng_Q4_Q1'].mean()
print("Mean is", mean_util, "and median is", median_util)
# Out:
# Mean is 0.7122223758269972 and median is 0.702

# %%
plt.boxplot(df['Avg_Utilization_Ratio'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18a04008850>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18a04009f90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18a03fffc50>],
#  'medians': [<matplotlib.lines.Line2D at 0x18a0400b550>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18a0401c150>],
#  'means': []}

# %%
util_percentiles = df['Avg_Utilization_Ratio'].quantile([0.0, 0.05, 0.1, 0.25, 0.5, 0.6, 0.7, 0.75, 0.80, 0.85, 0.86, 0.87, 0.89, 0.90, 0.91, 0.92, 0.93, 0.94, 0.95, 0.96, 0.97, 0.975, 0.98, 0.99, 1.00])
round(util_percentiles, 2)
# Out:
# 0.000    0.00
# 0.050    0.00
# 0.100    0.00
# 0.250    0.02
# 0.500    0.18
# 0.600    0.28
# 0.700    0.43
# 0.750    0.50
# 0.800    0.57
# 0.850    0.64
# 0.860    0.65
# 0.870    0.66
# 0.890    0.69
# 0.900    0.71
# 0.910    0.72
# 0.920    0.74
# 0.930    0.76
# 0.940    0.77
# 0.950    0.79
# 0.960    0.81
# 0.970    0.84
# 0.975    0.85
# 0.980    0.87
# 0.990    0.91
# 1.000    1.00
# Name: Avg_Utilization_Ratio, dtype: float64

# %%
median_util = df['Avg_Utilization_Ratio'].median()
mean_util = df['Avg_Utilization_Ratio'].mean()
print("Mean is", mean_util, "and median is", median_util)
# Out:
# Mean is 0.2748935518909845 and median is 0.176

# %% [markdown]
# ### Feature Engineering & Model Building

# %%
df.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %%
df.dtypes
# Out:
# CLIENTNUM                     int64
# Attrition_Flag               object
# Customer_Age                  int64
# Gender                       object
# Dependent_count               int64
# Education_Level              object
# Marital_Status               object
# Income_Category              object
# Card_Category                object
# Months_on_book                int64
# Total_Relationship_Count      int64
# Months_Inactive_12_mon        int64
# Contacts_Count_12_mon         int64
# Credit_Limit                float64
# Total_Revolving_Bal           int64
# Avg_Open_To_Buy             float64
# Total_Amt_Chng_Q4_Q1        float64
# Total_Trans_Amt               int64
# Total_Trans_Ct                int64
# Total_Ct_Chng_Q4_Q1         float64
# Avg_Utilization_Ratio       float64
# util_new                    float64
# dtype: object

# %%
sns.heatmap(pd.crosstab(df['Income_Category'], df['Card_Category']), annot = True)
# Out:
# <Axes: xlabel='Card_Category', ylabel='Income_Category'>

# %% [markdown]
# ### Building Model and Feature Engineering

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, classification_report

# %%
le_Gender = LabelEncoder()

# %%
df['Income_Category_Labelled'] = le_Gender.fit_transform(df['Income_Category'])
df['Education_Level_Labelled'] = le_Gender.fit_transform(df['Education_Level'])
df['Card_Category_Labelled'] = le_Gender.fit_transform(df['Card_Category'])

# %%
df = df.drop([ 'Education_Level',  'Income_Category', 'Card_Category','CLIENTNUM'], axis = 1)

# %%
df['Attrition_Flag'] = df['Attrition_Flag'].map({'Existing Customer' : 1,'Attrited Customer':0})

# %%
new_df = pd.get_dummies(df, columns=['Gender','Marital_Status'], drop_first=True, dtype = 'int')

# %%
new_df.dtypes
# Out:
# Attrition_Flag                int64
# Customer_Age                  int64
# Dependent_count               int64
# Months_on_book                int64
# Total_Relationship_Count      int64
# Months_Inactive_12_mon        int64
# Contacts_Count_12_mon         int64
# Credit_Limit                float64
# Total_Revolving_Bal           int64
# Avg_Open_To_Buy             float64
# Total_Amt_Chng_Q4_Q1        float64
# Total_Trans_Amt               int64
# Total_Trans_Ct                int64
# Total_Ct_Chng_Q4_Q1         float64
# Avg_Utilization_Ratio       float64
# util_new                    float64
# Income_Category_Labelled      int32
# Education_Level_Labelled      int32
# Card_Category_Labelled        int32
# Gender_M                      int32
# Marital_Status_Married        int32
# Marital_Status_Single         int32
# Marital_Status_Unknown        int32
# dtype: object

# %%
new_df = new_df.drop('util_new', axis = 1)

# %%
new_df.head()
# Out:
#    Attrition_Flag  Customer_Age  Dependent_count  Months_on_book  \
# 0               1            45                3              39
# 1               1            49                5              44
# 2               1            51                3              36
# 3               1            40                4              34
# 4               1            40                3              21
#
#    Total_Relationship_Count  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0                         5                       1                      3
# 1                         6                       1                      2
# 2                         4                       1                      0
# 3                         3                       4                      1
# 4                         5                       1                      0
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  ...  Total_Trans_Ct  \
# ...

# %%
train = new_df.drop('Attrition_Flag', axis = 1)
test = new_df['Attrition_Flag']

# %%
x_train, x_test, y_train, y_test = train_test_split(train, test, test_size = 0.19, random_state = 20)

# %%
# Linear Regression
lr_model = LogisticRegression()
lr_model.fit(x_train, y_train)
lr_predictions = lr_model.predict(x_test)
lr_accuracy = accuracy_score(y_test, lr_predictions)

# Naive Bayes Classifier
nb_model = GaussianNB()
nb_model.fit(x_train, y_train)
nb_predictions = nb_model.predict(x_test)
nb_accuracy = accuracy_score(y_test, nb_predictions)
# Out:
# c:\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ### Model Validation (Accuracy, Classification report)

# %%
# Print accuracy for each model
print("Linear Regression: ", lr_accuracy)
print("Naive Bayes Accuracy:", nb_accuracy)

# Generate classification reports for each model
print("\nLinear Regression Report:")
print(classification_report(y_test, lr_predictions))

print("\nNaive Bayes Classification Report:")
print(classification_report(y_test, nb_predictions))
# Out:
# Linear Regression:  0.8950649350649351
# Naive Bayes Accuracy: 0.8976623376623377
#
# Linear Regression Report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.54      0.61       287
#            1       0.92      0.96      0.94      1638
#
#     accuracy                           0.90      1925
#    macro avg       0.81      0.75      0.77      1925
# weighted avg       0.89      0.90      0.89      1925
#
#
# Naive Bayes Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.63      0.65       287
#            1       0.94      0.94      0.94      1638
#
#     accuracy                           0.90      1925
#    macro avg       0.80      0.79      0.79      1925
# weighted avg       0.90      0.90      0.90      1925

# %% [markdown]
# ### Prediction by user

# %%
X = new_df.drop('Attrition_Flag', axis = 1)

def predict(user_input, model):
    user_input = [float(input(f"Enter {column}: ")) for column in X.columns]
    prediction = model.predict([user_input])
    return prediction

while True:
    print("Choose a model to predict (1 for Logistic Regression, 2 for Naive Bayes, 3 to exit):")
    choice = input()
    if choice == "1":
        prediction = predict(X.columns, lr_model)
        print(f'Logistic Regression Prediction: {prediction[0]}')
    elif choice == "2":
        prediction = predict(X.columns, nb_model)
        print(f'Naive Bayes Prediction: {prediction[0]}')
    elif choice == "3":
        break
    else:
        print("Invalid choice.")
        break
# Out:
# Choose a model to predict (1 for Logistic Regression, 2 for Naive Bayes, 3 to exit):
# c:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# Logistic Regression Prediction: 1
# Choose a model to predict (1 for Logistic Regression, 2 for Naive Bayes, 3 to exit):
# Invalid choice. Please enter 1, 2, or 3 to exit.
# Choose a model to predict (1 for Logistic Regression, 2 for Naive Bayes, 3 to exit):
# Invalid choice. Please enter 1, 2, or 3 to exit.
# Choose a model to predict (1 for Logistic Regression, 2 for Naive Bayes, 3 to exit):
# Invalid choice. Please enter 1, 2, or 3 to exit.
# Choose a model to predict (1 for Logistic Regression, 2 for Naive Bayes, 3 to exit):
# Invalid choice. Please enter 1, 2, or 3 to exit.
# Choose a model to predict (1 for Logistic Regression, 2 for Naive Bayes, 3 to exit):
# Invalid choice. Please enter 1, 2, or 3 to exit.
# ...
